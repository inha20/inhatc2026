# %%
import pandas as pd
import numpy as np

# %%
s=pd.Series(["Sam",np.nan,"Tim","Kim"])
s
# Out:
# 0    Sam
# 1    NaN
# 2    Tim
# 3    Kim
# dtype: object

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
s.notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# dtype: bool

# %%
s[3]=None
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
s.dropna()
# Out:
# 0    Sam
# 2    Tim
# dtype: object

# %%
s
# Out:
# 0     Sam
# 1     NaN
# 2     Tim
# 3    None
# dtype: object

# %%
s.dropna(inplace=True)

# %%
s
# Out:
# 0    Sam
# 2    Tim
# dtype: object

# %%
print(pd.NA)
print(pd.NaT)
# Out:
# <NA>
# NaT

# %%
# 1
df1 = pd.DataFrame([[1, 2, 3], [4, np.nan, 5], [np.nan, np.nan, np.nan]])

# %%
df1.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# dtype: object

# %%
# np.nan은 숫자이기 때문에 float 타입의 컬럼에서 그대로 있음
df1
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  4.0  NaN  5.0
# 2  NaN  NaN  NaN

# %%
# 2
df2 = pd.DataFrame([[1.0, 2.0], [None, 4.0]])

# %%
df2.dtypes
# Out:
# 0    float64
# 1    float64
# dtype: object

# %%
# None은 숫자가 아니기 때문에 float 타입의 컬럼에서 np.nan으로 변환
df2
# Out:
#      0    1
# 0  1.0  2.0
# 1  NaN  4.0

# %%
# 3

# 차이는 dtype="Int64"으로 타입을 정했는지의 여부
df3 = pd.DataFrame({"a": [1, None, 3]})
df4 = pd.DataFrame({"a": pd.Series([1, None, 3], dtype="Int64")})

# %%
df3
# Out:
#      a
# 0  1.0
# 1  NaN
# 2  3.0

# %%
df4
# Out:
#       a
# 0     1
# 1  <NA>
# 2     3

# %%
# 4
# NA를 사용한 이유

df5 = pd.DataFrame({"a": [1, None, 3]}) 
# 값 [1, None, 3]은 None을 np.nan으로 바꾸기만 하면 float64이 되네?
# None → np.nan이 되면서 원래는 정수였던 1, 3까지도 실수 타입으로 바뀌어 버림

print(df5.dtypes)
# Out:
# a    float64
# dtype: object

# %%
df6 = pd.DataFrame({"a": pd.array([1, None, 3], dtype="Int64")})
# 값 1, 3은 정수라고 명시적으로 알림
# 이 경우 None은 np.nan이 아닌 pd.NA로 변환

# %%
df6
# Out:
#       a
# 0     1
# 1  <NA>
# 2     3

# %%
# 정리하면
# 결측치는 세 종류
# 1. 실수(float) → np.nan
# 2. 정수(Int64) → pd.NA
# 3. 날짜/시간 → pd.NaT

# 문자열의 경우도 pd.NA

df = pd.DataFrame({"a": pd.array(["hello", None, "world"], dtype="string")})
df
# Out:
#        a
# 0  hello
# 1   <NA>
# 2  world

# %%
df=pd.DataFrame([[1,2,3],[4, np.nan, 5],
                 [np.nan, np.nan, np.nan]])
df
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  4.0  NaN  5.0
# 2  NaN  NaN  NaN

# %%
df.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# dtype: object

# %%
df.dropna() # ---------- 대상은 np.nan, pd.NA, pd.NaT
# Out:
#      0    1    2
# 0  1.0  2.0  3.0

# %%
df.dropna(how="all")
# how="any" (디폴트) → 행에 하나라도 결측치가 있으면 제거
# how="all" → 행의 모든 값이 결측치일 때만 제거
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  4.0  NaN  5.0

# %%
df.fillna(0,inplace=True)
df

# %%
df=pd.DataFrame([[1, 2, 3],[4, pd.NA, 5],
                 [pd.NA, pd.NA, pd.NA]])
df
# Out:
#       0     1     2
# 0     1     2     3
# 1     4  <NA>     5
# 2  <NA>  <NA>  <NA>

# %%
df.fillna(0)
# Out:
# C:\Users\jongy\AppData\Local\Temp\ipykernel_6964\516507702.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(0)
#    0  1  2
# 0  1  2  3
# 1  4  0  5
# 2  0  0  0

# %%
df = pd.DataFrame({
    "실수": [1.0, np.nan, 3.0],
    "정수": pd.array([1, None, 3], dtype="Int64"),
    "날짜": pd.to_datetime(["2024-01-01", None, "2024-01-03"]),
    "문자": pd.array(["hello", None, "world"], dtype="string"),
})

# %%
df
# Out:
#     실수    정수         날짜     문자
# 0  1.0     1 2024-01-01  hello
# 1  NaN  <NA>        NaT   <NA>
# 2  3.0     3 2024-01-03  world

# %%
df.dropna()
# Out:
#     실수  정수         날짜     문자
# 0  1.0   1 2024-01-01  hello
# 2  3.0   3 2024-01-03  world

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "a": [1.0, np.nan, np.nan, 4.0],
    "b": [2.0, np.nan, 3.0,   np.nan],
    "c": [3.0, np.nan, 4.0,   5.0],
})
print(df)
# Out:
#      a    b    c
# 0  1.0  2.0  3.0
# 1  NaN  NaN  NaN
# 2  NaN  3.0  4.0
# 3  4.0  NaN  5.0

# %%
# 1. how="any" (디폴트) → 하나라도 결측치면 제거
df.dropna(how="any")
# Out:
#      a    b    c
# 0  1.0  2.0  3.0

# %%
# 2. how="all" → 모두 결측치일 때만 제거
df.dropna(how="all")
# Out:
#      a    b    c
# 0  1.0  2.0  3.0
# 2  NaN  3.0  4.0
# 3  4.0  NaN  5.0

# %%
# 3. thresh=2 → 결측치가 아닌 값이 2개 이상인 행만 유지
df.dropna(thresh=2)
# Out:
#      a    b    c
# 0  1.0  2.0  3.0
# 2  NaN  3.0  4.0
# 3  4.0  NaN  5.0

# %%
# 4. subset → 특정 컬럼만 기준으로 삼기
# a 컬럼 기준, a가 NaN인 행만 제거
df.dropna(subset=["a"])
# Out:
#      a    b    c
# 0  1.0  2.0  3.0
# 3  4.0  NaN  5.0

# %%
df
# Out:
#      a    b    c
# 0  1.0  2.0  3.0
# 1  NaN  NaN  NaN
# 2  NaN  3.0  4.0
# 3  4.0  NaN  5.0

# %%
# 5. axis=1 → 행이 아닌 열 기준으로 제거
df.dropna(axis=1, how="any")
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]
